# %% [markdown]
# <a href="https://colab.research.google.com/github/BrendaG04/HousePricePredictor/blob/main/InClassKNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from google.colab import drive
from sklearn import metrics

# %%
drive.mount('/content/drive/')
file_path = '/content/drive/My Drive/AmesHousing.csv'
df = pd.read_csv(file_path)
# Out:
# Mounted at /content/drive/

# %%
df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2   NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
# 3   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 4   NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
#
#   Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# ...

# %%
print("Feature names: ", df.columns)
# Out:
# Feature names:  Index(['Order', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
# ...

# %% [markdown]
# ## **Exercise 1**

# %%
X = df[["Gr Liv Area", "Bedroom AbvGr", "Full Bath"]]
y = df["SalePrice"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)


model = KNeighborsRegressor(n_neighbors=10)
model.fit(X_train_scaled, y_train)

prediction = model.predict(X_test_scaled)

# %%
X_test1 = pd.DataFrame([{
    "Gr Liv Area": 1800,
    "Bedroom AbvGr": 3,
    "Full Bath": 2
}])
X_test1_scaled = scaler.transform(X_test1)

prediction_ex1 = model.predict(X_test1_scaled)
print("Exercise 1 predicted sales price:", prediction_ex1[0])
# Out:
# Exercise 1 predicted sales price: 225340.0

# %% [markdown]
# ## **Exercise 2**

# %%
X = df[['Neighborhood']]
y = df['SalePrice']

# %%
le = LabelEncoder()
X_encoded = le.fit_transform(X['Neighborhood'])

# %%
X_encoded = X_encoded.reshape(-1, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_encoded,y , test_size=0.2)

# %%
model2 = KNeighborsRegressor(n_neighbors=10)
model2.fit(X_train, y_train)

prediction = model2.predict(X_test)

# %%
X_test2 = pd.DataFrame({
    "Neighborhood": df["Neighborhood"].unique()
})
X_test2_encoded = le.transform(X_test2["Neighborhood"])
X_test2_encoded = X_test2_encoded.reshape(-1, 1)
ex2_predictions = model2.predict(X_test2_encoded)

results = pd.DataFrame({
    "Neighborhood": X_test2["Neighborhood"],
    "PredictedPrice": ex2_predictions
})

print(results)
# Out:
#    Neighborhood  PredictedPrice
# 0         NAmes        150780.0
# 1       Gilbert        198332.7
# 2       StoneBr        282728.0
# 3        NWAmes        188240.0
# 4       Somerst        227984.6
# 5        BrDale        100420.0
# 6       NPkVill        138995.0
# 7       NridgHt        307570.0
# 8       Blmngtn        203115.6
# 9       NoRidge        292140.0
# 10      SawyerW        170292.6
# 11       Sawyer        137690.0
# 12       Greens        193950.0
# 13      BrkSide        127300.0
# 14      OldTown        124320.0
# 15       IDOTRR        115390.0
# 16      ClearCr        180643.2
# 17        SWISU        149428.4
# 18      Edwards        130290.0
# 19      CollgCr        236950.0
# 20      Crawfor        234680.0
# 21      Blueste        154440.0
# 22      Mitchel        184250.0
# 23       Timber        269810.0
# 24      MeadowV        102495.0
# 25      Veenker        257695.0
# 26      GrnHill        154200.0
# 27      Landmrk        111455.0

# %% [markdown]
# Knn is taking the average of the 10 nearest neighborhoods from the one we are trying to predict.

# %% [markdown]
# ## **Exercise 3**

# %%
X = df[[
    "Gr Liv Area",
    "Bedroom AbvGr",
    "Full Bath",
    "House Style",
    "Neighborhood"
]].copy()

y = df["SalePrice"]

# %%
le_style = LabelEncoder()
le_neigh = LabelEncoder()

X["House Style"] = le_style.fit_transform(X["House Style"])
X["Neighborhood"] = le_neigh.fit_transform(X["Neighborhood"])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
scaler = StandardScaler()
numeric_cols = ["Gr Liv Area", "Bedroom AbvGr", "Full Bath"]
X_train_scaled = X_train.copy()
X_train_scaled[numeric_cols] = scaler.fit_transform(X_train[numeric_cols])

X_test_scaled = X_test.copy()
X_test_scaled[numeric_cols] = scaler.transform(X_test[numeric_cols])1

# %%
model3 = KNeighborsRegressor(n_neighbors=10)
model3.fit(X_train_scaled, y_train)

y_pred = model3.predict(X_test_scaled)

# %%
test_home = pd.DataFrame([{
    "Gr Liv Area": 1800,
    "Bedroom AbvGr": 3,
    "Full Bath": 2,
    "House Style": "2Story",
    "Neighborhood": "Veenker"
}])

test_home["House Style"] = le_style.transform(test_home["House Style"])
test_home["Neighborhood"] = le_neigh.transform(test_home["Neighborhood"])


test_home[numeric_cols] = scaler.transform(test_home[numeric_cols])
prediction_ex3 = model3.predict(test_home)
print("Exercise 3 predicted sales price:", prediction_ex3[0])
# Out:
# Exercise 3 predicted sales price: 227745.5

# %% [markdown]
# **Exercise 1 only uses size, bedrooms, and bathrooms as features to predict the salesprice**
#
# **Exercise 2 only uses neighorhood as the feature, and the the label is the average neighborhood price for each town.**
#
# **Exercise 3 uses size, bedrooms, bathrooms, house style, adn neighborhood as featues. The model predcition is more accurate because it takes more details into consideration.**
